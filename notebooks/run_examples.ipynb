# %%
import json
import jsonschema
import os
import urllib
from zipfile import ZipFile

# %cd ..
# Out:
# /Users/cl/Documents/masters/maDMP-rocrates-maDMP

# %%
class color:
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'

def read_json_from_url(url):
    response = urllib.request.urlopen(url)
    data = json.loads(response.read())
    return data


def read_json_local(path):
    with open(path, 'r') as in_file:
        data = json.load(in_file)
    return data


def check_valid_dmp(dmp, schema):
    print(color.BOLD + 'Checking if valid maDMP' + color.END)
    try:
        jsonschema.validate(instance=dmp, schema=schema)
        print(color.GREEN + 'VALID' + color.END)
        valid = 1
    except Exception as e:
        valid = 0
        print(color.RED + 'NOT VALID' + color.END)
        print('with the following exceptions:\n')
        print(e)
        pass
    return valid
    

def extract_zip(file_path_local, path_local):
    with ZipFile(file_path_local, 'r') as zipObj:
       # Extract all the contents of zip file in current directory
       zipObj.extractall(path_local)


def get_filename(path_local):
    file_list = os.listdir(path_local)
    file_path_local = [filename for filename in file_list \
                       if filename.find('.zip') == -1 \
                       and filename.find('.json') >= 0 \
                       and filename != 'dmp_from_rocrates.json']
    return file_path_local[0]

    
def save_url_to_disk(path, url):
    filename = os.path.split(url)[-1]
    dirname = filename.split('.')[0]
    path_local = os.path.join(path, dirname)
    if not os.path.isdir(path_local):
        os.mkdir(path_local)
    
    file_path_local = os.path.join(path, dirname, filename)
    urllib.request.urlretrieve(url, file_path_local)
    if not filename.find('zip') == -1:
        extract_zip(file_path_local, path_local)
    
    json_filename = get_filename(path_local)
    file_path_local = os.path.join(path_local, json_filename)
    # data = read_json_local(file_path_local)
    return file_path_local

# %% [markdown]
# ## run dmp to rocrates and back to dmp examples

# %%
dmp_examples = [
    'https://zenodo.org/record/3758653/files/dmp.zip',  # 10.5281/zenodo.3758653
    'https://zenodo.org/record/3754740/files/SwedishMotorInsurance_maDMP_Sibincic.zip',
    'https://zenodo.org/record/3742227/files/maDMP_COVID-19_GoldPrice_analysis.zip',
    'https://zenodo.org/record/3738548/files/dsue1-part3-madmp-01627775.json.zip',
    'https://zenodo.org/record/3749776/files/mDMP_01625723.zip',
    'https://raw.githubusercontent.com/RDA-DMP-Common/RDA-DMP-Common-Standard/master/examples/JSON/ex9-dmp-long.json',
    'https://raw.githubusercontent.com/RDA-DMP-Common/RDA-DMP-Common-Standard/master/examples/JSON/ex8-dmp-minimal-content.json',
    'https://raw.githubusercontent.com/RDA-DMP-Common/RDA-DMP-Common-Standard/master/examples/JSON/ex7-dataset-many.json',
    'https://raw.githubusercontent.com/RDA-DMP-Common/RDA-DMP-Common-Standard/master/examples/JSON/ex6-dataset-closed.json',
    'https://raw.githubusercontent.com/RDA-DMP-Common/RDA-DMP-Common-Standard/master/examples/JSON/ex5-dataset-planned-host.json',
]

path = 'examples'
url_schema = 'https://raw.githubusercontent.com/RDA-DMP-Common/RDA-DMP-Common-Standard/master/examples/JSON/JSON-schema/1.0/maDMP-schema-1.0.json'
maDMP_schema = read_json_from_url(url_schema)
for url in dmp_examples:
    print(url)
    file_path_local  = save_url_to_disk(path, url)
    print(file_path_local)
    dmp = read_json_local(file_path_local)
    valid = check_valid_dmp(dmp, maDMP_schema)
    
    if valid:
        print(color.BOLD + 'converting maDMP to rocrates' + color.END)
        # %run src/madmp_to_rocrates.py --path $file_path_local
        print(color.BOLD + 'converting rocrates to maDMP' + color.END)
        dir_path_local = os.path.split(file_path_local)[0]
        # %run src/rocrates_to_madmp.py --path $dir_path_local
        print('#'*80)
        print(color.BOLD + 'comparing original and recreated maDMPS' + color.END)
        print('#'*80)
        d2_path = os.path.join(dir_path_local, 'dmp_from_rocrates.json')
        # %run src/compare_dictionaries.py --path_d1 $file_path_local --path_d2 $d2_path
        print('#'*80)
        print(color.BOLD + 'done' + color.END)
        print('#'*80 + '\n'*3)
# Out:
# https://zenodo.org/record/3758653/files/dmp.zip
# examples/dmp/dmp.json
# Checking if valid maDMP
# VALID
# converting maDMP to rocrates
# Checking if valid maDMP
# VALID
# processing dataset 1 of 2 datasets
# processing dataset 2 of 2 datasets
# converting rocrates to maDMP
# Checking if valid maDMP
# VALID
# ################################################################################
# comparing original and recreated maDMPS
# ################################################################################
# comparing d1 to d2:
# dmp :
#  -  title  :  Hypertree Decompositions for Query Optimization in Postgres
#  +  title  :  DMP created from rocrates
# dmp :
#  -  description  :  Development and Benchmark of a new strategy for query execution. The data is collected for the purpose of benchmarking the new, optimized queries and measure the effectiveness of the technique against the default postgres
# optimizer
#  +  description  :  a RDA-DMP-Common-Standard maDMP created from rocrate manifests
# dmp->contact->dmp_id :
#  -  identifier  :  10.5281/zenodo.3758547
#  +  identifier  :
# dmp->contact->dmp_id :
#  -  type  :  doi
#  +  type  :  other
# dmp->contact->dmp_id :
# issued as key not in d2
#
# dmp->contact->dmp_id->dataset_id :
#  -  type  :  url
#  +  type  :  other
# dmp->contact->dmp_id->dataset_id :
# data_quality_assurance as key not in d2
#
# dmp->contact->dmp_id->dataset_id :
#  -  personal_data  :  no
#  +  personal_data  :  unknown
# dmp->contact->dmp_id->dataset_id :
#  -  sensitive_data  :  no
#  +  sensitive_data  :  unknown
# dmp->contact->dmp_id->dataset_id :
# access_url as key not in d2
#
# dmp->contact->dmp_id->dataset_id->host :
# availability as key not in d2
#
# dmp->contact->dmp_id->dataset_id->host :
# support_versioning as key not in d2
#
# dmp->contact->dmp_id->dataset_id->host :
# pid_system as key not in d2
#
# dmp->contact->dmp_id->dataset_id :
#  -  type  :  doi
#  +  type  :  other
# dmp->contact->dmp_id->dataset_id :
#  -  personal_data  :  no
#  +  personal_data  :  unknown
# dmp->contact->dmp_id->dataset_id :
#  -  sensitive_data  :  no
#  +  sensitive_data  :  unknown
# dmp->contact->dmp_id->dataset_id :
# data_quality_assurance as key not in d2
#
# dmp->contact->dmp_id->dataset_id :
# access_url as key not in d2
#
# dmp->contact->dmp_id->dataset_id->host :
# availability as key not in d2
#
# dmp->contact->dmp_id->dataset_id->host :
# support_versioning as key not in d2
#
# dmp->contact->dmp_id->dataset_id->host :
# pid_system as key not in d2
#
# ################################################################################
# done
# ################################################################################
#
#
#
# https://zenodo.org/record/3754740/files/SwedishMotorInsurance_maDMP_Sibincic.zip
# examples/SwedishMotorInsurance_maDMP_Sibincic/SwedishMotorInsurance_maDMP_Sibincic.json
# Checking if valid maDMP
# VALID
# converting maDMP to rocrates
# Checking if valid maDMP
# VALID
# processing dataset 1 of 1 datasets
# converting rocrates to maDMP
# Checking if valid maDMP
# VALID
# ################################################################################
# comparing original and recreated maDMPS
# ################################################################################
# comparing d1 to d2:
# dmp->dmp_id :
#  -  identifier  :  https://doi.org/10.5281/zenodo.3753030
#  +  identifier  :
# dmp->dmp_id :
#  -  type  :  doi
#  +  type  :  other
# dmp->dmp_id :
#  -  title  :  Predicting total payments in Swedish Motor Insurance
#  +  title  :  DMP created from rocrates
# dmp->dmp_id :
#  -  description  :  The experiment is based on Swedish Motor Insurance data set which describes third party automobile insurance claims for the year 1977 in Sweden. The goal here was to analyze the data and to perform simple linear regression for the 2 points of interest in this dataset: number of claims (the frequency) and sum of payments (the severity). In order to do that, we had to split the dataset into training and test set, apply predictions in the test set according to a training and to come up with measures for our predictions
#  +  description  :  a RDA-DMP-Common-Standard maDMP created from rocrate manifests
# dmp->dmp_id->contact->dataset_id :
#  -  type  :  url
#  +  type  :  other
# dmp->dmp_id->contact->dataset_id :
# issued as key not in d2
#
# dmp->dmp_id->contact->dataset_id :
# language as key not in d2
#
# dmp->dmp_id->contact->dataset_id :
#  -  personal_data  :  no
#  +  personal_data  :  unknown
# dmp->dmp_id->contact->dataset_id :
#  -  sensitive_data  :  no
#  +  sensitive_data  :  unknown
# dmp->dmp_id->contact->dataset_id->host :
# support_versioning as key not in d2
#
# dmp->dmp_id->contact->dataset_id :
# metadata as key not in d2
#
# dmp->dmp_id->contact->funder_id :
#  -  type  :  url
#  +  type  :  other
# ################################################################################
# done
# ################################################################################
#
#
#
# https://zenodo.org/record/3742227/files/maDMP_COVID-19_GoldPrice_analysis.zip
# examples/maDMP_COVID-19_GoldPrice_analysis/maDMP_COVID-19_GoldPrice_analysis.json
# Checking if valid maDMP
# VALID
# converting maDMP to rocrates
# Checking if valid maDMP
# VALID
# processing dataset 1 of 4 datasets
# processing dataset 2 of 4 datasets
# processing dataset 3 of 4 datasets
# processing dataset 4 of 4 datasets
# converting rocrates to maDMP
# Checking if valid maDMP
# VALID
# ################################################################################
# comparing original and recreated maDMPS
# ################################################################################
# comparing d1 to d2:
# dmp :
#  -  title  :  COVID-19 Gold Price Analysis
#  +  title  :  DMP created from rocrates
# dmp :
#  -  description  :  The current global Corona crisis not only has a huge impact on health systems around the world, but also on the economic situation. Gold is traditionally known to be a go-to asset in times of crisis and uncertainty and its price therefore usually increases when stock indices collapse. However, the Austrian newspaper Kurier recently published an article (https://kurier.at/wirtschaft/coronavirus-verliert-gold-seinen-ruf-als-krisenwaehrung/400787762) claiming that current market activity during the Corona crisis contradicts this theory. They also state that the gold price will stabilize again in the medium term as this also happened on other occasions. This experiment aims at a data-driven approach to make validations of these assumptions easier. The development of the number of Corona cases and deaths in each country over time is compared to the corresponding gold prices. Since we have not yet overcome the current situation, validating assumptions about medium-term consequences on the gold price cannot be made now, but might be with future data.
#  +  description  :  a RDA-DMP-Common-Standard maDMP created from rocrate manifests
# dmp->dmp_id :
#  -  identifier  :  https://doi.org/10.5281/zenodo.3742227
#  +  identifier  :
# dmp->dmp_id :
#  -  type  :  doi
#  +  type  :  other
# dmp->dmp_id->contact->dataset_id :
#  -  type  :  doi
#  +  type  :  other
# dmp->dmp_id->contact->dataset_id :
#  -  personal_data  :  no
#  +  personal_data  :  unknown
# dmp->dmp_id->contact->dataset_id :
#  -  sensitive_data  :  no
#  +  sensitive_data  :  unknown
# dmp->dmp_id->contact->dataset_id :
# download_url as key not in d2
#
# dmp->dmp_id->contact->dataset_id :
# metadata as key not in d2
#
# dmp->dmp_id->contact->dataset_id :
#  -  type  :  doi
#  +  type  :  other
# dmp->dmp_id->contact->dataset_id :
#  -  personal_data  :  no
#  +  personal_data  :  unknown
# dmp->dmp_id->contact->dataset_id :
#  -  sensitive_data  :  no
#  +  sensitive_data  :  unknown
# dmp->dmp_id->contact->dataset_id :
# download_url as key not in d2
#
# dmp->dmp_id->contact->dataset_id :
#  -  type  :  url
#  +  type  :  other
# dmp->dmp_id->contact->dataset_id :
#  -  personal_data  :  no
#  +  personal_data  :  unknown
# dmp->dmp_id->contact->dataset_id :
#  -  sensitive_data  :  no
#  +  sensitive_data  :  unknown
# dmp->dmp_id->contact->dataset_id :
# download_url as key not in d2
#
# dmp->dmp_id->contact->dataset_id :
#  -  type  :  doi
#  +  type  :  other
# dmp->dmp_id->contact->dataset_id :
#  -  personal_data  :  no
#  +  personal_data  :  unknown
# dmp->dmp_id->contact->dataset_id :
#  -  sensitive_data  :  no
#  +  sensitive_data  :  unknown
# dmp->dmp_id->contact->dataset_id :
# download_url as key not in d2
#
# dmp->dmp_id->contact->dataset_id :
# metadata as key not in d2
# ################################################################################
# done
# ################################################################################
#
#
#
# https://zenodo.org/record/3738548/files/dsue1-part3-madmp-01627775.json.zip
# examples/dsue1-part3-madmp-01627775/dsue1-part3-madmp-01627775.json
# Checking if valid maDMP
# VALID
# converting maDMP to rocrates
# Checking if valid maDMP
# VALID
# processing dataset 1 of 1 datasets
# converting rocrates to maDMP
# Checking if valid maDMP
# VALID
# ################################################################################
# comparing original and recreated maDMPS
# ################################################################################
# comparing d1 to d2:
# dmp->dmp_id :
#  -  identifier  :  https://doi.org/10.5281/zenodo.3737787
#  +  identifier  :
# dmp->dmp_id :
#  -  type  :  doi
#  +  type  :  other
# dmp->dmp_id :
#  -  title  :  Finding patterns in the internet's highest rated movies
#  +  title  :  DMP created from rocrates
# dmp->dmp_id :
#  -  description  :  The purpose of this experiment is to find out whether or not certain "patterns" can be found in popular movies. Maybe there are certain decades that produced a much higher number of popular movies than others, maybe certain actresses*actors are featured more frequently than others. Are there certain genres which are more popular than the rest? This data could not only be useful for film studios, but also for TV broadcasters or streaming services.
#  +  description  :  a RDA-DMP-Common-Standard maDMP created from rocrate manifests
# dmp->dmp_id->contact->dataset_id :
#  -  type  :  url
#  +  type  :  other
# dmp->dmp_id->contact->dataset_id :
# issued as key not in d2
#
# dmp->dmp_id->contact->dataset_id :
# language as key not in d2
#
# dmp->dmp_id->contact->dataset_id :
#  -  personal_data  :  no
#  +  personal_data  :  unknown
# dmp->dmp_id->contact->dataset_id :
#  -  sensitive_data  :  no
#  +  sensitive_data  :  unknown
# dmp->dmp_id->contact->dataset_id :
# data_quality_assurance as key not in d2
#
# dmp->dmp_id->contact->dataset_id->host :
# support_versioning as key not in d2
#
# dmp->dmp_id->contact->dataset_id :
# metadata as key not in d2
#
# dmp->dmp_id->contact->funder_id :
#  -  type  :  url
#  +  type  :  other
# ################################################################################
# done
# ################################################################################
#
#
#
# https://zenodo.org/record/3749776/files/mDMP_01625723.zip
# examples/mDMP_01625723/mDMP_01625723.json
# Checking if valid maDMP
# VALID
# converting maDMP to rocrates
# Checking if valid maDMP
# VALID
# processing dataset 1 of 1 datasets
# converting rocrates to maDMP
# Checking if valid maDMP
# VALID
# ################################################################################
# comparing original and recreated maDMPS
# ################################################################################
# comparing d1 to d2:
# dmp :
#  -  title  :  Corona data analysis tool mDMP
#  +  title  :  DMP created from rocrates
# dmp :
#  -  description  :  In this project we have implemented a tool for calculating statistical data for a corona virus data set. Several statistics, e.g. top ten countries with most cases worldwide are calculated and displayed visually in interactive plots.
#  +  description  :  a RDA-DMP-Common-Standard maDMP created from rocrate manifests
# dmp->dmp_id :
#  -  identifier  :  10.5281/zenodo.3749776
#  +  identifier  :
# dmp->dmp_id :
#  -  type  :  doi
#  +  type  :  other
# dmp->dmp_id->contact :
# project_id_type as key not in d2
#
# dmp->dmp_id->contact->dataset_id :
#  -  type  :  doi
#  +  type  :  other
# dmp->dmp_id->contact->dataset_id :
#  -  personal_data  :  no
#  +  personal_data  :  unknown
# dmp->dmp_id->contact->dataset_id :
#  -  sensitive_data  :  no
#  +  sensitive_data  :  unknown
# dmp->dmp_id->contact->dataset_id->host :
# host_id_type as key not in d2
#
# dmp->dmp_id->contact->dataset_id->host :
# supports_versioning as key not in d2
#
# dmp->dmp_id->contact->dataset_id->host :
# storage_type as key not in d2
#
# dmp->dmp_id->contact->dataset_id->host :
# pid_system as key not in d2
#
# ################################################################################
# done
# ################################################################################
#
#
#
# https://raw.githubusercontent.com/RDA-DMP-Common/RDA-DMP-Common-Standard/master/examples/JSON/ex9-dmp-long.json
# examples/ex9-dmp-long/ex9-dmp-long.json
# Checking if valid maDMP
# VALID
# converting maDMP to rocrates
# Checking if valid maDMP
# VALID
# processing dataset 1 of 3 datasets
# processing dataset 2 of 3 datasets
# processing dataset 3 of 3 datasets
# converting rocrates to maDMP
# Checking if valid maDMP
# VALID
# ################################################################################
# comparing original and recreated maDMPS
# ################################################################################
# comparing d1 to d2:
# dmp :
#  -  title  :  DMP for our new project
#  +  title  :  DMP created from rocrates
# dmp :
#  -  description  :  This DMP is for our new project.
#  +  description  :  a RDA-DMP-Common-Standard maDMP created from rocrate manifests
# dmp->dmp_id :
#  -  identifier  :  https://doi.org/10.0000/00.0.1234
#  +  identifier  :
# dmp->dmp_id :
#  -  type  :  doi
#  +  type  :  other
# dmp->dmp_id->contact :
# project_id_type as key not in d2
#
# dmp->dmp_id->contact :
# funder_name as key not in d2
#
# dmp->dmp_id->contact->dataset_id :
#  -  personal_data  :  no
#  +  personal_data  :  unknown
# dmp->dmp_id->contact->dataset_id :
#  -  sensitive_data  :  no
#  +  sensitive_data  :  unknown
# dmp->dmp_id->contact->dataset_id->host :
# host_id_type as key not in d2
#
# dmp->dmp_id->contact->dataset_id->host :
# supports_versioning as key not in d2
#
# dmp->dmp_id->contact->dataset_id->host :
# storage_type as key not in d2
#
# dmp->dmp_id->contact->dataset_id->host :
# pid_system as key not in d2
#
# dmp->dmp_id->contact->dataset_id :
#  -  personal_data  :  no
#  +  personal_data  :  unknown
# dmp->dmp_id->contact->dataset_id :
#  -  sensitive_data  :  yes
#  +  sensitive_data  :  unknown
# dmp->dmp_id->contact->dataset_id :
#  -  personal_data  :  yes
#  +  personal_data  :  unknown
# dmp->dmp_id->contact->dataset_id :
#  -  sensitive_data  :  no
#  +  sensitive_data  :  unknown
# dmp->dmp_id->contact->dataset_id->host :
# host_id_type as key not in d2
#
# dmp->dmp_id->contact->dataset_id->host :
# supports_versioning as key not in d2
#
# dmp->dmp_id->contact->dataset_id->host :
# storage_type as key not in d2
#
# dmp->dmp_id->contact->dataset_id->host :
# pid_system as key not in d2
#
# ################################################################################
# done
# ################################################################################
#
#
#
# https://raw.githubusercontent.com/RDA-DMP-Common/RDA-DMP-Common-Standard/master/examples/JSON/ex8-dmp-minimal-content.json
# examples/ex8-dmp-minimal-content/ex8-dmp-minimal-content.json
# Checking if valid maDMP
# VALID
# converting maDMP to rocrates
# Checking if valid maDMP
# VALID
# processing dataset 1 of 1 datasets
# converting rocrates to maDMP
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/Documents/masters/maDMP-rocrates-maDMP/src/rocrates_to_madmp.py in <module>
#     351     args = parser.parse_args()
#     352
# --> 353     rocrates_to_madmp(args.path, args.path_schema, mappings, args.dmp_identifier)
#
# ~/Documents/masters/maDMP-rocrates-maDMP/src/rocrates_to_madmp.py in rocrates_to_madmp(path, path_schema, mappings, dmp_identifier)
#     321     dmp_header['dataset'] = datasets
#     322     # add some defaults for missing keys
# --> 323     test_rocrate_dmp(dmp_header)
#     324     dmp_from_rocrate['dmp'] = dmp_header
#     325     #print(json.dumps(dmp_from_rocrate, indent=4))
#
# ~/Documents/masters/maDMP-rocrates-maDMP/src/rocrates_to_madmp.py in test_rocrate_dmp(dmp_header)
#     293         dmp_header['language'] = 'eng'
#     294     for dataset in dmp_header['dataset']:
# --> 295         for distribution in dataset['distribution']:
#     296             if not 'data_access' in distribution:
#     297                 distribution['data_access'] = 'closed'
#
# KeyError: 'distribution'
# ################################################################################
# comparing original and recreated maDMPS
# ################################################################################
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/Documents/masters/maDMP-rocrates-maDMP/src/compare_dictionaries.py in <module>
#      83
#      84     d1 = read_json_local(args.path_d1)
# ---> 85     d2 = read_json_local(args.path_d2)
#      86     print ("comparing d1 to d2:")
#      87     report = findDiff(d1,d2)
#
# ~/Documents/masters/maDMP-rocrates-maDMP/src/compare_dictionaries.py in read_json_local(path)
#      27
#      28 def read_json_local(path):
# ---> 29     with open(path, 'r') as in_file:
#      30         data = json.load(in_file)
#      31     return data
#
# FileNotFoundError: [Errno 2] No such file or directory: 'examples/ex8-dmp-minimal-content/dmp_from_rocrates.json'
# ################################################################################
# done
# ################################################################################
#
#
#
# https://raw.githubusercontent.com/RDA-DMP-Common/RDA-DMP-Common-Standard/master/examples/JSON/ex7-dataset-many.json
# examples/ex7-dataset-many/ex7-dataset-many.json
# Checking if valid maDMP
# VALID
# converting maDMP to rocrates
# Checking if valid maDMP
# VALID
# processing dataset 1 of 2 datasets
# processing dataset 2 of 2 datasets
# converting rocrates to maDMP
# Checking if valid maDMP
# VALID
# ################################################################################
# comparing original and recreated maDMPS
# ################################################################################
# comparing d1 to d2:
# dmp :
#  -  title  :  DMP with two datasets
#  +  title  :  DMP created from rocrates
# dmp :
#  -  description  :  DMP describing more than one dataset
#  +  description  :  a RDA-DMP-Common-Standard maDMP created from rocrate manifests
# dmp->contact->dmp_id :
#  -  identifier  :  https://doi.org/10.0000/00.0.1234
#  +  identifier  :
# dmp->contact->dmp_id :
#  -  type  :  doi
#  +  type  :  other
# dmp->contact->dmp_id :
# issued as key not in d2
#
# dmp->contact->dmp_id->dataset_id :
#  -  type  :  doi
#  +  type  :  other
# dmp->contact->dmp_id->dataset_id :
#  -  personal_data  :  no
#  +  personal_data  :  unknown
# dmp->contact->dmp_id :
# issued as key not in d2
#
# dmp->contact->dmp_id->dataset_id :
#  -  type  :  doi
#  +  type  :  other
# dmp->contact->dmp_id->dataset_id :
#  -  personal_data  :  no
#  +  personal_data  :  unknown
# dmp->contact->dmp_id->dataset_id :
#  -  sensitive_data  :  no
#  +  sensitive_data  :  unknown
# dmp->contact->dmp_id->dataset_id :
# data_quality_assurance as key not in d2
#
# dmp->contact->dmp_id->dataset_id :
# access_url as key not in d2
#
# ################################################################################
# done
# ################################################################################
#
#
#
# https://raw.githubusercontent.com/RDA-DMP-Common/RDA-DMP-Common-Standard/master/examples/JSON/ex6-dataset-closed.json
# examples/ex6-dataset-closed/ex6-dataset-closed.json
# Checking if valid maDMP
# VALID
# converting maDMP to rocrates
# Checking if valid maDMP
# VALID
# processing dataset 1 of 1 datasets
# converting rocrates to maDMP
# Checking if valid maDMP
# VALID
# ################################################################################
# comparing original and recreated maDMPS
# ################################################################################
# comparing d1 to d2:
# dmp :
#  -  title  :  Super secret data DMP
#  +  title  :  DMP created from rocrates
# dmp :
#  -  description  :  DMP with super secret and sensitive data that cannot be shared
#  +  description  :  a RDA-DMP-Common-Standard maDMP created from rocrate manifests
# dmp->contact->dmp_id :
#  -  identifier  :  https://doi.org/10.0000/00.0.1234
#  +  identifier  :
# dmp->contact->dmp_id :
#  -  type  :  doi
#  +  type  :  other
# dmp->contact->dmp_id :
#  -  personal_data  :  yes
#  +  personal_data  :  unknown
# dmp->contact->dmp_id :
#  -  sensitive_data  :  yes
#  +  sensitive_data  :  unknown
# dmp->contact->dmp_id->dataset_id :
#  -  type  :  doi
#  +  type  :  other
# dmp->contact->dmp_id->dataset_id :
# security_and_privacy as key not in d2
#
# dmp->contact->dmp_id->dataset_id :
# data_quality_assurance as key not in d2
#
# dmp->contact->dmp_id->dataset_id :
# preservation_statement as key not in d2
#
# ################################################################################
# done
# ################################################################################
#
#
#
# https://raw.githubusercontent.com/RDA-DMP-Common/RDA-DMP-Common-Standard/master/examples/JSON/ex5-dataset-planned-host.json
# examples/ex5-dataset-planned-host/ex5-dataset-planned-host.json
# Checking if valid maDMP
# VALID
# converting maDMP to rocrates
# Checking if valid maDMP
# VALID
# processing dataset 1 of 1 datasets
# converting rocrates to maDMP
# Checking if valid maDMP
# VALID
# ################################################################################
# comparing original and recreated maDMPS
# ################################################################################
# comparing d1 to d2:
# dmp :
#  -  title  :  Estimation DMP
#  +  title  :  DMP created from rocrates
# dmp :
#  -  description  :  DOI pre-booked for data, it's size is estimated
#  +  description  :  a RDA-DMP-Common-Standard maDMP created from rocrate manifests
# dmp->contact->dmp_id :
#  -  identifier  :  https://doi.org/10.0000/00.0.1234
#  +  identifier  :
# dmp->contact->dmp_id :
#  -  type  :  doi
#  +  type  :  other
# dmp->contact->dmp_id :
# issued as key not in d2
#
# dmp->contact->dmp_id :
#  -  personal_data  :  no
#  +  personal_data  :  unknown
# dmp->contact->dmp_id :
#  -  sensitive_data  :  no
#  +  sensitive_data  :  unknown
# dmp->contact->dmp_id->dataset_id :
#  -  type  :  doi
#  +  type  :  other
# dmp->contact->dmp_id->dataset_id->host :
# supports_versioning as key not in d2
#
# dmp->contact->dmp_id->dataset_id->host :
# backup_frequency as key not in d2
#
# dmp->contact->dmp_id->dataset_id->host :
# storage_type as key not in d2
#
# dmp->contact->dmp_id->dataset_id->host :
# availability as key not in d2
#
# ################################################################################
# done
# ################################################################################

# %% [markdown]
# ## run rocrate to dmp examples

# %%
rocrate_examples = [
    'examples/simple-dataset-0.1.0'
]

url_schema = 'https://raw.githubusercontent.com/RDA-DMP-Common/RDA-DMP-Common-Standard/master/examples/JSON/JSON-schema/1.0/maDMP-schema-1.0.json'
maDMP_schema = read_json_from_url(url_schema)
for file_path in rocrate_examples:
    print('#'*80)
    print(file_path)
    print(color.BOLD + 'converting rocrates to maDMP' + color.END)
    # %run src/rocrates_to_madmp.py --path $file_path
    print('#'*80 + '\n'*3)
# Out:
# ################################################################################
# examples/simple-dataset-0.1.0
# converting rocrates to maDMP
# argh
# Checking if valid maDMP
# VALID
# ################################################################################
